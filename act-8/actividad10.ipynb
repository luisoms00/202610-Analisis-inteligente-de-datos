# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data = {
    'Comisiones_Y': [
        22, 13, 33, 38, 23, 47, 29, 38, 41, 32, 20, 13, 47, # Columna izquierda
        38, 44, 29, 38, 37, 14, 34, 25, 27, 25, 43, 34      # Columna derecha
    ],
    'Llamadas_X2': [
        139, 132, 144, 142, 142, 142, 138, 139, 144, 134, 135, 137, 146,
        146, 144, 147, 144, 149, 131, 144, 132, 132, 127, 154, 147
    ],
    'Millas_X1': [
        2371, 2226, 2731, 3351, 2289, 3449, 3114, 3342, 2842, 2625, 2121, 2219, 3463,
        3290, 3103, 2122, 2791, 3209, 2287, 2848, 2690, 2933, 2671, 2988, 2829
    ]
}


df = pd.DataFrame(data)


correlacion = df.corr()


print("--- Matriz de Correlación ---")
print(correlacion)
print("\n")


plt.figure(figsize=(8, 6))
sns.heatmap(correlacion, annot=True, cmap='coolwarm', vmin=-1, vmax=1, linewidths=0.5)
plt.title('Gráfica de Correlación: Comisiones, Llamadas y Millas')
plt.show()


sns.pairplot(df, kind='reg')
plt.show()
# Out:
# --- Matriz de Correlación ---
#               Comisiones_Y  Llamadas_X2  Millas_X1
# Comisiones_Y      1.000000     0.679716   0.832271
# Llamadas_X2       0.679716     1.000000   0.401075
# Millas_X1         0.832271     0.401075   1.000000
