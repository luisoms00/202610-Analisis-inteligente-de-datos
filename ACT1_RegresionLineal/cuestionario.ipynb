# %% [markdown]
# ## 1. ¿Por qué era importante evaluar si existe una relación entre la cantidad de palabras y la cantidad de shares de un artículo?
#
# ### Para poder predecir cuantas veces se compartia un articulo en redes sociales a partir de sus caracteristicas. Se evaluo la relacion Word Count contra Shares para determinar si la loingitud del texto es un factor determinante en la viralidad.

# %% [markdown]
# ## 2. Al analizar los histogramas iniciales, ¿qué patrones observaste en la distribución de palabras y shares? ¿Cómo influye esto en la selección del modelo?
#
# ### Analizando los resultados obtenidos, podemos apreciar que mientras menor el WorkCount, se presentan mas shares. Un modelo lineal simple es buena idea para una primer aproximacion, pero tiende a jalar los valores altos.

# %% [markdown]
# ## 3. ¿Qué propósito tuvo filtrar los artículos con menos de 3500 palabras y menos de 80,000 shares? ¿Cómo cambió el comportamiento del modelo después del filtrado?
#
# ### El fin de filtar fue enfocarnos en la zona alta de registros, asi omitimos datos poco relevantes, ademas, despues de filtrar observamos que la nube de puntos ahora es mas compacto.

# %% [markdown]
# ## 4. ¿Por qué crees que había tanta concentración de puntos en estas zonas? ¿Cómo afecta esto al desempeño de la regresión lineal?
#
# ### La gran mayoria de los articulos tiene un desempeño promedio, la regresion lineal asume una relacion constante y proporcional, al tener una nube densa en valores bajos y pocos puntos muy lejanos y altos, la linea de regresion podria ser pobre.

# %% [markdown]
# ## 5.En el modelo de regresión simple, ¿qué significa la pendiente del modelo respecto a la relación Word Count → Shares? Explica en tus palabras.
#
# ### La tasa de crecimiento se estima en base a los shares en funcion de la longitud del texto.

# %% [markdown]
# ## 6. El error cuadrático medio (MSE) fue alto en el primer modelo. ¿Qué factores en los datos podrían explicar este resultado?
#
# ### Podriamos decir que hay una alta dispersion en los puntos mas bajos

# %% [markdown]
# ## 7. Observa el R² obtenido: ¿Crees que la cantidad de palabras es un buen predictor de los shares? ¿Por qué sí o por qué no?
#
# ### Al tener un R2 bajo, no podemos tener claridad en los datos, la cantidad de palabras no explica bien por si sola cuantos shares tendra un articulo.

# %% [markdown]
# ## 8. En los gráficos que distinguen artículos por encima y por debajo de la media (1808 palabras), ¿qué diferencias observaste en la dispersión?
#
# ### Los articulos mas largos presentan dispersion mas larga, mientras los cortos tienden a quedarse a la izquierda.

# %% [markdown]
# ## 9. ¿Te parece que la línea de regresión se ajusta bien a los datos? Argumenta basándote en la dispersión.
# ### No, porque la linea no atraviesa todos los puntos contenidos en la nube.
